# %%
import pyautogui as pa
import pyperclip as pc# importa uma biblioteca que permite o uso de caracteres especiais
import time as tm # importa uma biblioteca que permite uma pausa

# pyautogui.click -> clicar
# pyautogui.write -> escrever
# pyautogui.press -> pressionar
# pyautogui.hotkey -> atalho
# pyaoutogui.position(x=n,y=n, clicks=2) -> clicar na posição desejada 
# pyautogui.PAUSE = 1 -> pausa de 1 segundo

#Código para verificar a posição do mouse
################################
# import time                  #
# time.sleep(3)                #    
# print(pyautogui.position())  #
################################

# Abrir o chrome
pa.press('win')                               # Pressiona a tecla windows
pa.PAUSE = 1                                  # Pausa de 1 segundo
pa.write('chrome')                            # Escreve o texto na pesquisa
pa.PAUSE = 1                                  # Pausa de 1 segundo
pa.press('enter')                             # Pressiona a tecla enter


# Entrar no link
pa.write('https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga')   # Escreve o texto na guia
pa.PAUSE = 1                                  # Pausa de 1 segundo
pa.press('enter')                             # Pressiona a tecla enter
tm.sleep(3)                                   # Aguarda 3 segundos


# Navegar até o arquivo
pa.click(x=2266, y=274, clicks=2)             # Clica na pasta do arquivo
tm.sleep(4)                                   # Aguarda 4 segundos


# Fazer download
pa.click(x=2283, y=335, button='right')       # Clica com o botão esquerdo no arquivo
pa.click(x=2382, y=813)                       # Clica para fazer o download
tm.sleep(5)                                   # Aguarda 5 segundos

# %%
import pandas as pd


# Sempre antes de passar o caminho de um arquivo colocar o "r" antes. r de raw, especifíca o cru.
tabela = pd.read_excel(r"C:\Users\Eduardo\Downloads\Vendas - Dez.xlsx")   # Define tabela ao arquivo baixado

display(tabela)   # Exibe a tabela baixada

faturamento = tabela["Valor Final"].sum()   # Realiza a soma da coluna faturamento
quantidade = tabela["Quantidade"].sum()     # Realiza a soma da coluna quantidade
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
import time as tm
import pyautogui as pa
import pyperclip as pc

# Aguardar antes de entrar no gmail
tm.sleep(3)                                 # Aguarda 3 segundos
pa.click(x=2529, y=700)                     # Clica na tela


# Entrar no gmail
pa.hotkey('ctrl', 'n')                      # Abre uma nova guia
pc.copy('https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox')   # Copia o texto
pa.hotkey('ctrl', 'v')                      # Cola o texto na guia
pa.press('enter')                           # Pressiona a tecla enter
tm.sleep(3)                                 # Aguarda 3 segundos


# Escrever e-mail
pa.click(x=2015, y=189)                     # Clica no e-mail
pa.write('eduardocastros257@gmail.com')     # Escreve o remetente
pa.press('tab')                             # Pressiona o tab
pa.press('tab')                             # Pressiona o tab
pa.write('Teste de Automação em python')    # Escreve o assunto
pa.press('tab')                             # Pressiona o tap

texto = f"""Prezado, bom dia!
Segue abaixo o relatório semanal da planilha de vendas da nossa empresa

O faturamento foi de: R${faturamento:,.2f}
A quantidade de produtos foi de: R${quantidade:,.2f}

Atenciosamente,
Eduardo Nogueira."""

pc.copy(texto)                              # Copia o texto padrão
pa.hotkey('ctrl' , 'v')                     # Cola o texto no corpo do e-mail
pa.click(x=2591, y=967)                     # Clica para enviar
tm.sleep(3)                                 # Aguarda 3 segundos
pa.click(x=3195, y=17)                      # Fecha a primeira aba
tm.sleep(1)                                 # Aguarda 1 segundo
pa.click(x=3195, y=17)                      # Fecha a segunda aba
